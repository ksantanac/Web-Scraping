# %% [markdown]
# ## Executando HTML diretamente

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(markup='<p> Olá Mundo!</p>')
soup
# Out:
# <html><body><p> Olá Mundo!</p></body></html>

# %%
soup = BeautifulSoup(markup='''
                     
    <h1 id="titulo" class="titulo">Programador Aventureiro</h1>
    <h2 id="subtitulo" class="subtitulo">Chegou a hora de você dominar de vez a programação</h2>
    <h3 id="texto-intro" class="texto-intro">Todo o conhecimento necessário para se tornar um profissional de alto valor no mercado</h3>
    <p id="paragrafo" class="lista-beneficios">Benefícios de estudar conosco:</p>
    <ul id="lista-beneficios" class="lista-beneficios">
        <li class="item-beneficio comunidade">Comunidade de alunos engajada e ativa</li>
        <li class="item-beneficio certificado-profissional">Certificados de conclusão para cada curso</li>
        <li class="item-beneficio">Atualizações e novos conteúdos todos os meses</li>
        <li class="item-beneficio">Aulas gravadas pra assistir no seu ritmo</li>
        <li class="item-beneficio">Metodologia validada por milhares de alunos</li>
        <li id="tipos-de-acesso" class="item-beneficio">Opção de obter acesso vitalício ou assinatura com benefícios adicionais</li>
    </ul>
                     
''')
soup
# Out:
# <html><body><h1 class="titulo" id="titulo">Programador Aventureiro</h1>
# <h2 class="subtitulo" id="subtitulo">Chegou a hora de você dominar de vez a programação</h2>
# <h3 class="texto-intro" id="texto-intro">Todo o conhecimento necessário para se tornar um profissional de alto valor no mercado</h3>
# <p class="lista-beneficios" id="paragrafo">Benefícios de estudar conosco:</p>
# <ul class="lista-beneficios" id="lista-beneficios">
# <li class="item-beneficio comunidade">Comunidade de alunos engajada e ativa</li>
# <li class="item-beneficio certificado-profissional">Certificados de conclusão para cada curso</li>
# <li class="item-beneficio">Atualizações e novos conteúdos todos os meses</li>
# <li class="item-beneficio">Aulas gravadas pra assistir no seu ritmo</li>
# <li class="item-beneficio">Metodologia validada por milhares de alunos</li>
# <li class="item-beneficio" id="tipos-de-acesso">Opção de obter acesso vitalício ou assinatura com benefícios adicionais</li>
# </ul>
# ...

# %% [markdown]
# ## Abrindo HTML de um arquivo de texto

# %%
with open('sourcecode/exemplo1.html') as file:
    html = file.read()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 with open('sourcecode/exemplo1.html') as file:
#       2     html = file.read()
#
# File c:\Users\anjos\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'sourcecode/exemplo1.html'

# %%
from IPython.display import HTML
HTML(html)
# Out:
# <!DOCTYPE html>
# <html lang="pt">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Curso de Web Scrapping | Programador Aventureiro</title>
#     <link rel="icon" href="logo.jpg" type="image/jpg">
# </head>
# <body>
#     <i><!-- Título da página --></i>
#     <h1 id="titulo" class="titulo">Programador Aventureiro</h1>
#     <h2 id="subtitulo" class="subtitulo">Chegou a hora de você dominar de vez a programação</h2>
#     <h3 id="texto-intro" class="texto-intro">Todo o conhecimento necessário para se tornar um profissional de alto valor no mercado</h3>
#
#     <i><!-- Lista de benefícios --></i>
#     <p id="paragrafo" class="lista-beneficios">Benefícios de estudar conosco:</p>
#     <ul id="lista-beneficios" class="lista-beneficios">
#         <li class="item-beneficio comunidade">Comunidade de alunos engajada e ativa</li>
# ...

# %%
soup = BeautifulSoup(markup=html)
soup
# Out:
# <!DOCTYPE html>
# <html lang="pt">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <title>Curso de Web Scrapping | Programador Aventureiro</title>
# <link href="logo.jpg" rel="icon" type="image/jpg"/>
# </head>
# <body>
# <i><!-- Título da página --></i>
# <h1 class="titulo" id="titulo">Programador Aventureiro</h1>
# <h2 class="subtitulo" id="subtitulo">Chegou a hora de você dominar de vez a programação</h2>
# <h3 class="texto-intro" id="texto-intro">Todo o conhecimento necessário para se tornar um profissional de alto valor no mercado</h3>
# <i><!-- Lista de benefícios --></i>
# <p class="lista-beneficios" id="paragrafo">Benefícios de estudar conosco:</p>
# <ul class="lista-beneficios" id="lista-beneficios">
# <li class="item-beneficio comunidade">Comunidade de alunos engajada e ativa</li>
# <li class="item-beneficio certificado-profissional">Certificados de conclusão para cada curso</li>
# ...

# %% [markdown]
# ## Lendo de fontes online com Requests

# %%
import requests

page = requests.get('https://google.com')

# %%
BeautifulSoup(page.text)
# Out:
# <!DOCTYPE html>
# ...

# %%
# from IPython.display import HTML
# HTML(page.text)

# %% [markdown]
# ## Lendo de fontes online com Selenium

# %%
from selenium import webdriver

# %%
driver = webdriver.Chrome()
driver.get('https://google.com')

driver.page_source
# Out:
# '<html itemscope="" itemtype="http://schema.org/WebPage" lang="pt-BR"><head><meta charset="UTF-8"><meta content="origin" name="referrer"><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"><title>Google</title><script src="https://apis.google.com/_/scs/abc-static/_/js/k=gapi.gapi.en.iZZZ0XsR8bM.O/m=gapi_iframes,googleapis_client/rt=j/sv=1/d=1/ed=1/am=AAAQ/rs=AHpOoo_0-97nH_2IxP0suYF105-PdJv4zg/cb=gapi.loaded_0" nonce="" async=""></script><script nonce="">(function(){var _g={kEI:\'fIOIZvaREqn25OUPwJylqAI\',kEXPI:\'31\',kBL:\'oRHn\',kOPI:89978449};(function(){var a;((a=window.google)==null?0:a.stvsc)?google.kEI=_g.kEI:window.google=_g;}).call(this);})();(function(){google.sn=\'webhp\';google.kHL=\'pt-BR\';})();(function(){\nvar h=this||self;function l(){return window.google!==void 0&&window.google.kOPI!==void 0&&window.google.kOPI!==0?window.google.kOPI:null};var m,n=[];function p(a){for(var b;a&&(!a.getAttribute||!(b=a.getAttribute("eid")));)a=
# ...

# %%
BeautifulSoup(driver.page_source)
# Out:
# <html itemscope="" itemtype="http://schema.org/WebPage" lang="pt-BR"><head><meta charset="utf-8"/><meta content="origin" name="referrer"/><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"/><title>Google</title><script async="" nonce="" src="https://apis.google.com/_/scs/abc-static/_/js/k=gapi.gapi.en.iZZZ0XsR8bM.O/m=gapi_iframes,googleapis_client/rt=j/sv=1/d=1/ed=1/am=AAAQ/rs=AHpOoo_0-97nH_2IxP0suYF105-PdJv4zg/cb=gapi.loaded_0"></script><script nonce="">(function(){var _g={kEI:'fIOIZvaREqn25OUPwJylqAI',kEXPI:'31',kBL:'oRHn',kOPI:89978449};(function(){var a;((a=window.google)==null?0:a.stvsc)?google.kEI=_g.kEI:window.google=_g;}).call(this);})();(function(){google.sn='webhp';google.kHL='pt-BR';})();(function(){
# ...

# %%
driver.quit()

# %%
# Forma concisa
with webdriver.Chrome() as driver:
    driver.get('https://google.com')
    soup = BeautifulSoup(driver.page_source)

# %%
soup
# Out:
# <html itemscope="" itemtype="http://schema.org/WebPage" lang="pt-BR"><head><meta charset="utf-8"/><meta content="origin" name="referrer"/><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"/><title>Google</title><script async="" nonce="" src="https://apis.google.com/_/scs/abc-static/_/js/k=gapi.gapi.en.iZZZ0XsR8bM.O/m=gapi_iframes,googleapis_client/rt=j/sv=1/d=1/ed=1/am=AAAQ/rs=AHpOoo_0-97nH_2IxP0suYF105-PdJv4zg/cb=gapi.loaded_0"></script><script nonce="">(function(){var _g={kEI:'hoOIZqa0MaWBhuMPvqabuAM',kEXPI:'31',kBL:'oRHn',kOPI:89978449};(function(){var a;((a=window.google)==null?0:a.stvsc)?google.kEI=_g.kEI:window.google=_g;}).call(this);})();(function(){google.sn='webhp';google.kHL='pt-BR';})();(function(){
# ...
